# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from tensorflow.python.client import device_lib

print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15137420176542622667
# ]

# %%
import numpy as np
import pandas as pd
from collections import defaultdict
import re

from bs4 import BeautifulSoup

import sys
import os

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils.np_utils import to_categorical

from keras.layers import Embedding
from keras.layers import Dense, Input, Flatten
from keras.layers import Conv1D, MaxPooling1D, Embedding, Dropout
from keras.models import Model

MAX_SEQUENCE_LENGTH = 1000
MAX_NB_WORDS = 200000
EMBEDDING_DIM = 100
VALIDATION_SPLIT = 0.2

# %%
def clean_str(string):
    """
    Cleaning of dataset
    """
    string = re.sub(r"\\", "", string)    
    string = re.sub(r"\'", "", string)    
    string = re.sub(r"\"", "", string)    
    return string.strip().lower()

# %%
data_train = pd.read_csv('C:/Users/spcbe/Documents/GitHub/dataset/snopes_training_dataset.csv')
data_train
# Out:
#                                              snopes_page         topic  \
# 0      http://www.snopes.com/georgia-bans-muslim-cult...      politics
# 1      http://www.snopes.com/georgia-bans-muslim-cult...      politics
# 2      http://www.snopes.com/georgia-bans-muslim-cult...      politics
# 3      http://www.snopes.com/georgia-bans-muslim-cult...      politics
# 4      http://www.snopes.com/georgia-bans-muslim-cult...      politics
# 5      http://www.snopes.com/georgia-bans-muslim-cult...      politics
# 6      http://www.snopes.com/georgia-bans-muslim-cult...      politics
# 7       http://www.snopes.com/chevy-suburban-kills-baby/  fauxtography
# 8       http://www.snopes.com/chevy-suburban-kills-baby/  fauxtography
# 9       http://www.snopes.com/chevy-suburban-kills-baby/  fauxtography
# 10      http://www.snopes.com/chevy-suburban-kills-baby/  fauxtography
# 11      http://www.snopes.com/chevy-suburban-kills-baby/  fauxtography
# 12      http://www.snopes.com/chevy-suburban-kills-baby/  fauxtography
# 13             http://www.snopes.com/science/equinox.asp       science
# 14     http://www.snopes.com/politics/business/matrix...      business
# 15     http://www.snopes.com/politics/business/matrix...      business
# 16     http://www.snopes.com/politics/business/matrix...      business
# 17                   http://www.snopes.com/topiary-cats/  fauxtography
# 18                   http://www.snopes.com/topiary-cats/  fauxtography
# 19                   http://www.snopes.com/topiary-cats/  fauxtography
# 20                   http://www.snopes.com/topiary-cats/  fauxtography
# 21            http://www.snopes.com/cheese-phone-pocket/  fauxtography
# 22            http://www.snopes.com/cheese-phone-pocket/  fauxtography
# 23            http://www.snopes.com/cheese-phone-pocket/  fauxtography
# 24            http://www.snopes.com/cheese-phone-pocket/  fauxtography
# 25            http://www.snopes.com/cheese-phone-pocket/  fauxtography
# 26            http://www.snopes.com/cheese-phone-pocket/  fauxtography
# 27      http://www.snopes.com/rowan-atkinson-death-hoax/     fake news
# 28      http://www.snopes.com/tom-price-cancer-patients/     fake news
# 29      http://www.snopes.com/tom-price-cancer-patients/     fake news
# ...                                                  ...           ...
# 16835  http://www.snopes.com/photos/advertisements/me...  fauxtography
# 16836  http://www.snopes.com/photos/advertisements/me...  fauxtography
# 16837  http://www.snopes.com/photos/advertisements/me...  fauxtography
# 16838     http://www.snopes.com/katrina/photos/buses.asp  fauxtography
# 16839  http://www.snopes.com/photos/airplane/mandarin...  fauxtography
# 16840        http://snopes.com//ecstasy-halloween-candy/       horrors
# 16841        http://snopes.com//ecstasy-halloween-candy/       horrors
# 16842        http://snopes.com//ecstasy-halloween-candy/       horrors
# 16843        http://snopes.com//ecstasy-halloween-candy/       horrors
# 16844        http://snopes.com//ecstasy-halloween-candy/       horrors
# 16845        http://snopes.com//ecstasy-halloween-candy/       horrors
# 16846        http://snopes.com//ecstasy-halloween-candy/       horrors
# 16847        http://snopes.com//ecstasy-halloween-candy/       horrors
# 16848        http://snopes.com//ecstasy-halloween-candy/       horrors
# 16849        http://snopes.com//ecstasy-halloween-candy/       horrors
# 16850          http://snopes.com//cassidy-boon-drowning/     fake news
# 16851          http://snopes.com//cassidy-boon-drowning/     fake news
# 16852                   http://snopes.com//nazi-minions/  fauxtography
# 16853                   http://snopes.com//nazi-minions/  fauxtography
# 16854                   http://snopes.com//nazi-minions/  fauxtography
# 16855                   http://snopes.com//nazi-minions/  fauxtography
# 16856                   http://snopes.com//nazi-minions/  fauxtography
# 16857                   http://snopes.com//nazi-minions/  fauxtography
# 16858     http://snopes.com//pope-changing-commandments/     fake news
# 16859        http://snopes.com//mexico-guatemala-border/  fauxtography
# 16860        http://snopes.com//mexico-guatemala-border/  fauxtography
# 16861        http://snopes.com//mexico-guatemala-border/  fauxtography
# 16862        http://snopes.com//mexico-guatemala-border/  fauxtography
# 16863        http://snopes.com//mexico-guatemala-border/  fauxtography
# 16864        http://snopes.com//mexico-guatemala-border/  fauxtography
#
#                                                    claim claim_label  \
# 0      Georgia recently became the first U.S. state t...       false
# 1      Georgia recently became the first U.S. state t...       false
# 2      Georgia recently became the first U.S. state t...       false
# 3      Georgia recently became the first U.S. state t...       false
# 4      Georgia recently became the first U.S. state t...       false
# 5      Georgia recently became the first U.S. state t...       false
# 6      Georgia recently became the first U.S. state t...       false
# 7      An Image depicts a fatal collision involving a...       false
# 8      An Image depicts a fatal collision involving a...       false
# 9      An Image depicts a fatal collision involving a...       false
# 10     An Image depicts a fatal collision involving a...       false
# 11     An Image depicts a fatal collision involving a...       false
# 12     An Image depicts a fatal collision involving a...       false
# 13     A special property of the equinox allows eggs ...       false
# 14     Sophia Stewart won a large judgment in a copyr...       false
# 15     Sophia Stewart won a large judgment in a copyr...       false
# 16     Sophia Stewart won a large judgment in a copyr...       false
# 17     Images show several large topiary cats created...       false
# 18     Images show several large topiary cats created...       false
# 19     Images show several large topiary cats created...       false
# 20     Images show several large topiary cats created...       false
# 21     A video shows Dutch politician Tunahan Kuzu pu...       false
# 22     A video shows Dutch politician Tunahan Kuzu pu...       false
# 23     A video shows Dutch politician Tunahan Kuzu pu...       false
# 24     A video shows Dutch politician Tunahan Kuzu pu...       false
# 25     A video shows Dutch politician Tunahan Kuzu pu...       false
# 26     A video shows Dutch politician Tunahan Kuzu pu...       false
# 27     British actor Rowan Atkinson, best known as 'M...       false
# 28     Tom Price said that it was 'better for our bud...       false
# 29     Tom Price said that it was 'better for our bud...       false
# ...                                                  ...         ...
# 16835  A video clip shows a meteorite striking a pick...       false
# 16836  A video clip shows a meteorite striking a pick...       false
# 16837  A video clip shows a meteorite striking a pick...       false
# 16838  Photograph shows school buses caught in a floo...     mixture
# 16839  Photograph shows a Mandarin Airlines flight ta...        true
# 16840  Parents should keep any eye out for drug-laced...      mfalse
# 16841  Parents should keep any eye out for drug-laced...      mfalse
# 16842  Parents should keep any eye out for drug-laced...      mfalse
# 16843  Parents should keep any eye out for drug-laced...      mfalse
# 16844  Parents should keep any eye out for drug-laced...      mfalse
# 16845  Parents should keep any eye out for drug-laced...      mfalse
# 16846  Parents should keep any eye out for drug-laced...      mfalse
# 16847  Parents should keep any eye out for drug-laced...      mfalse
# 16848  Parents should keep any eye out for drug-laced...      mfalse
# 16849  Parents should keep any eye out for drug-laced...      mfalse
# 16850  A woman named Cassidy Boon is suing the man wh...       false
# 16851  A woman named Cassidy Boon is suing the man wh...       false
# 16852  The Minions in the film "Despicable Me" were i...       false
# 16853  The Minions in the film "Despicable Me" were i...       false
# 16854  The Minions in the film "Despicable Me" were i...       false
# 16855  The Minions in the film "Despicable Me" were i...       false
# 16856  The Minions in the film "Despicable Me" were i...       false
# 16857  The Minions in the film "Despicable Me" were i...       false
# 16858  Pope Francis announced during a sermon that Go...       false
# 16859  Photographs show a border fence between the co...       false
# 16860  Photographs show a border fence between the co...       false
# 16861  Photographs show a border fence between the co...       false
# 16862  Photographs show a border fence between the co...       false
# 16863  Photographs show a border fence between the co...       false
# 16864  Photographs show a border fence between the co...       false
#
#        date_published    date_updated  \
# 0      Nov 17th, 2016  Mar 20th, 2017
# 1      Nov 17th, 2016  Mar 20th, 2017
# 2      Nov 17th, 2016  Mar 20th, 2017
# 3      Nov 17th, 2016  Mar 20th, 2017
# 4      Nov 17th, 2016  Mar 20th, 2017
# 5      Nov 17th, 2016  Mar 20th, 2017
# 6      Nov 17th, 2016  Mar 20th, 2017
# 7      Sep 16th, 2016  Mar 20th, 2017
# 8      Sep 16th, 2016  Mar 20th, 2017
# 9      Sep 16th, 2016  Mar 20th, 2017
# 10     Sep 16th, 2016  Mar 20th, 2017
# 11     Sep 16th, 2016  Mar 20th, 2017
# 12     Sep 16th, 2016  Mar 20th, 2017
# 13     Mar 17th, 1999  Mar 20th, 2017
# 14      Aug 8th, 2005  Mar 19th, 2017
# 15      Aug 8th, 2005  Mar 19th, 2017
# 16      Aug 8th, 2005  Mar 19th, 2017
# 17      Dec 9th, 2016  Mar 19th, 2017
# 18      Dec 9th, 2016  Mar 19th, 2017
# 19      Dec 9th, 2016  Mar 19th, 2017
# 20      Dec 9th, 2016  Mar 19th, 2017
# 21     Mar 18th, 2017             NaN
# 22     Mar 18th, 2017             NaN
# 23     Mar 18th, 2017             NaN
# 24     Mar 18th, 2017             NaN
# 25     Mar 18th, 2017             NaN
# 26     Mar 18th, 2017             NaN
# 27     Jul 15th, 2016  Mar 18th, 2017
# 28     Mar 17th, 2017             NaN
# 29     Mar 17th, 2017             NaN
# ...               ...             ...
# 16835  Nov 16th, 2005  Apr 21st, 2016
# 16836  Nov 16th, 2005  Apr 21st, 2016
# 16837  Nov 16th, 2005  Apr 21st, 2016
# 16838   Sep 6th, 2005  Jul 17th, 2016
# 16839  Jan 11th, 2005  Nov 25th, 2016
# 16840  Sep 29th, 2015  Oct 30th, 2016
# 16841  Sep 29th, 2015  Oct 30th, 2016
# 16842  Sep 29th, 2015  Oct 30th, 2016
# 16843  Sep 29th, 2015  Oct 30th, 2016
# 16844  Sep 29th, 2015  Oct 30th, 2016
# 16845  Sep 29th, 2015  Oct 30th, 2016
# 16846  Sep 29th, 2015  Oct 30th, 2016
# 16847  Sep 29th, 2015  Oct 30th, 2016
# 16848  Sep 29th, 2015  Oct 30th, 2016
# 16849  Sep 29th, 2015  Oct 30th, 2016
# 16850  Sep 29th, 2015   Feb 7th, 2017
# 16851  Sep 29th, 2015   Feb 7th, 2017
# 16852  Jul 20th, 2015  Jul 17th, 2016
# 16853  Jul 20th, 2015  Jul 17th, 2016
# 16854  Jul 20th, 2015  Jul 17th, 2016
# 16855  Jul 20th, 2015  Jul 17th, 2016
# 16856  Jul 20th, 2015  Jul 17th, 2016
# 16857  Jul 20th, 2015  Jul 17th, 2016
# 16858   Jul 7th, 2015  Mar 13th, 2017
# 16859  Aug 26th, 2015  Jan 27th, 2017
# 16860  Aug 26th, 2015  Jan 27th, 2017
# 16861  Aug 26th, 2015  Jan 27th, 2017
# 16862  Aug 26th, 2015  Jan 27th, 2017
# 16863  Aug 26th, 2015  Jan 27th, 2017
# 16864  Aug 26th, 2015  Jan 27th, 2017
#
#                                                 page_url  page_is_example  \
# 0      http://www.legis.ga.gov/Legislation/en-US/disp...            False
# 1      http://arabsinamerica.unc.edu/identity/veiling...            False
# 2            http://www.wisegeek.com/what-is-a-niqab.htm            False
# 3      http://www.wsbtv.com/news/local/new-bill-would...            False
# 4                     http://www.house-press.com/?p=6060            False
# 5      http://law.justia.com/cases/georgia/supreme-co...            False
# 6      https://www.shutterstock.com/image-photo/hand-...            False
# 7      https://www.facebook.com/photo.php?fbid=179409...            False
# 8      https://www.facebook.com/photo.php?fbid=101537...            False
# 9      http://www.wsbtv.com/news/local/three-tractor-...            False
# 10     http://www.livetrucking.com/four-tractor-trail...            False
# 11      https://en.wikipedia.org/wiki/Chevrolet_Suburban            False
# 12     http://www.livetrucking.com/mans-facebook-post...            False
# 13     https://www.shutterstock.com/image-photo/egg-s...            False
# 14     http://www.thaindian.com/newsportal/entertainm...            False
# 15     http://www.africanglobe.net/headlines/sophia-s...            False
# 16     https://www.shutterstock.com/image-illustratio...            False
# 17                  https://www.facebook.com/topiarycat/            False
# 18     http://www.bbc.com/news/uk-england-beds-bucks-...            False
# 19     http://www.bbc.com/news/uk-england-norfolk-275...            False
# 20                           http://thetopiarycat.co.uk/            False
# 21     http://www.rtlnieuws.nl/opmerkelijk/denk-leide...            False
# 22            https://twitter.com/hashtag/tosti?src=hash            False
# 23        https://twitter.com/hashtag/tostigate?src=hash            False
# 24     https://twitter.com/tunahankuzu/status/8427492...            False
# 25     https://twitter.com/tunahankuzu/status/8427492...            False
# 26     https://upload.wikimedia.org/wikipedia/commons...            False
# 27     https://www.shutterstock.com/image-photo/mosco...            False
# 28                       http://politicops.com/about-us/            False
# 29     https://commons.wikimedia.org/wiki/File:Tom_Pr...            False
# ...                                                  ...              ...
# 16835                                         bungee.asp            False
# 16836                      http://www.toyota.com/tacoma/            False
# 16837                http://www.methodstudios.com/mox808            False
# 16838  http://news.yahoo.com/news?tmpl=story&u=/05090...            False
# 16839                   http://www.drdisk.com.hk/sam.htm            False
# 16840  https://www.facebook.com/photo.php?fbid=104154...            False
# 16841  https://www.facebook.com/photo.php?fbid=804124...            False
# 16842  http://too-cute-3-blog.tumblr.com/post/8726858...            False
# 16843  http://www.mdmateam.com/post/84465172886/monty...            False
# 16844  https://www.google.com/search?q=ecstasy&num=50...            False
# 16845  http://www.laweekly.com/music/moon-rocks-the-b...            False
# 16846  https://www.facebook.com/806744919395572/photo...            False
# 16847  http://www.ajc.com/lifestyles/holiday/police-w...            False
# 16848  https://twitter.com/ajc/status/656912968584708...            False
# 16849  https://twitter.com/ajc/status/656912968584708096            False
# 16850  http://tvtropes.org/pmwiki/pmwiki.php/Main/Str...            False
# 16851  http://www.tineye.com/search/ee09e8802f7153cd3...            False
# 16852  https://www.facebook.com/photo.php?fbid=102071...            False
# 16853  https://twitter.com/1949QN2/status/62288932543...            False
# 16854  https://twitter.com/Morenoestatista/status/622...            False
# 16855                   http://imgur.com/gallery/HxiiXt4            False
# 16856  http://www.therebreathersite.nl/12_Atmospheric...            False
# 16857  http://gizmodo.com/5877926/12-deep-sea-diving-...            False
# 16858  http://realnewsrightnow.com/2015/07/pope-franc...            False
# 16859  https://www.facebook.com/1665478827021935/phot...            False
# 16860  https://www.quora.com/Does-Mexico-have-a-wall-...            False
# 16861  http://fusion.net/story/124671/as-mexico-tight...            False
# 16862  http://www.defendersblog.org/2013/06/on-the-li...            False
# 16863  http://www.i24news.tv/en/news/israel/diplomacy...            False
# 16864  http://www.vtjp.org/background/Separation_Wall...            False
#
#        page_is_image_credit  page_is_archived  page_is_first_citation  \
# 0                     False             False                    True
# 1                     False             False                   False
# 2                     False             False                   False
# 3                     False             False                   False
# 4                     False             False                   False
# 5                     False             False                   False
# 6                      True             False                   False
# 7                     False             False                    True
# 8                     False             False                   False
# 9                     False             False                   False
# 10                    False             False                   False
# 11                    False             False                   False
# 12                    False             False                   False
# 13                     True             False                   False
# 14                    False             False                    True
# 15                    False             False                   False
# 16                     True             False                   False
# 17                    False             False                    True
# 18                    False             False                   False
# 19                    False             False                   False
# 20                     True             False                   False
# 21                    False             False                    True
# 22                    False             False                   False
# 23                    False             False                   False
# 24                    False             False                   False
# 25                    False             False                   False
# 26                     True             False                   False
# 27                     True             False                   False
# 28                    False              True                    True
# 29                     True             False                   False
# ...                     ...               ...                     ...
# 16835                 False             False                    True
# 16836                 False             False                   False
# 16837                 False              True                   False
# 16838                 False             False                    True
# 16839                 False             False                    True
# 16840                 False             False                    True
# 16841                 False             False                   False
# 16842                 False             False                   False
# 16843                 False             False                   False
# 16844                 False             False                   False
# 16845                 False             False                   False
# 16846                 False             False                   False
# 16847                 False             False                   False
# 16848                 False             False                   False
# 16849                 False             False                   False
# 16850                 False             False                    True
# 16851                 False             False                   False
# 16852                 False             False                    True
# 16853                 False             False                   False
# 16854                 False             False                   False
# 16855                 False             False                   False
# 16856                 False             False                   False
# 16857                 False             False                   False
# 16858                 False              True                    True
# 16859                 False             False                    True
# 16860                 False             False                   False
# 16861                 False             False                   False
# 16862                 False             False                   False
# 16863                 False             False                   False
# 16864                 False             False                   False
#
#                                                     tags
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7      chevy-suburban,scolding,inaccurate-viral-photo...
# 8      chevy-suburban,scolding,inaccurate-viral-photo...
# 9      chevy-suburban,scolding,inaccurate-viral-photo...
# 10     chevy-suburban,scolding,inaccurate-viral-photo...
# 11     chevy-suburban,scolding,inaccurate-viral-photo...
# 12     chevy-suburban,scolding,inaccurate-viral-photo...
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 16835                                                NaN
# 16836                                                NaN
# 16837                                                NaN
# 16838                                                NaN
# 16839                                                NaN
# 16840  halloween-urban-legends,mdma,gummi-bears,molly...
# 16841  halloween-urban-legends,mdma,gummi-bears,molly...
# 16842  halloween-urban-legends,mdma,gummi-bears,molly...
# 16843  halloween-urban-legends,mdma,gummi-bears,molly...
# 16844  halloween-urban-legends,mdma,gummi-bears,molly...
# 16845  halloween-urban-legends,mdma,gummi-bears,molly...
# 16846  halloween-urban-legends,mdma,gummi-bears,molly...
# 16847  halloween-urban-legends,mdma,gummi-bears,molly...
# 16848  halloween-urban-legends,mdma,gummi-bears,molly...
# 16849  halloween-urban-legends,mdma,gummi-bears,molly...
# 16850  straw-feminism,cassidy-boon,fake-news,portly-g...
# 16851  straw-feminism,cassidy-boon,fake-news,portly-g...
# 16852  minions-nazi-photo,holocaust,despicable-me,zyk...
# 16853  minions-nazi-photo,holocaust,despicable-me,zyk...
# 16854  minions-nazi-photo,holocaust,despicable-me,zyk...
# 16855  minions-nazi-photo,holocaust,despicable-me,zyk...
# 16856  minions-nazi-photo,holocaust,despicable-me,zyk...
# 16857  minions-nazi-photo,holocaust,despicable-me,zyk...
# 16858                                                NaN
# 16859             politics,guatemala,donald-trump,mexico
# 16860             politics,guatemala,donald-trump,mexico
# 16861             politics,guatemala,donald-trump,mexico
# 16862             politics,guatemala,donald-trump,mexico
# 16863             politics,guatemala,donald-trump,mexico
# 16864             politics,guatemala,donald-trump,mexico
#
# [16865 rows x 12 columns]

# %%
# Input Data preprocessing
# data_train = pd.read_csv('C:/Users/spcbe/Documents/GitHub/Fake-News-Detection--master/dataset/train.csv')
#data_train['label'] = data_train['label'].replace('FAKE',1)
#data_train['label'] = data_train['label'].replace('REAL',0)
print(data_train.columns)
print('What the raw input data looks like:')
print(data_train[0:5])
list_labels = list(set(data_train.claim_label))
texts = []
labels = []

for i in range(data_train.topic.shape[0]):
    text1 = str(data_train.topic[i])
    text = str(data_train.claim[i])
    texts.append(text+text1)
    labels.append(list_labels.index(data_train.claim_label[i]))
    
tokenizer = Tokenizer(num_words=MAX_NB_WORDS)
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
# Out:
# Index(['snopes_page', 'topic', 'claim', 'claim_label', 'date_published',
#        'date_updated', 'page_url', 'page_is_example', 'page_is_image_credit',
#        'page_is_archived', 'page_is_first_citation', 'tags'],
#       dtype='object')
# What the raw input data looks like:
#                                          snopes_page     topic  \
# 0  http://www.snopes.com/georgia-bans-muslim-cult...  politics
# 1  http://www.snopes.com/georgia-bans-muslim-cult...  politics
# 2  http://www.snopes.com/georgia-bans-muslim-cult...  politics
# 3  http://www.snopes.com/georgia-bans-muslim-cult...  politics
# 4  http://www.snopes.com/georgia-bans-muslim-cult...  politics
#
#                                                claim claim_label  \
# 0  Georgia recently became the first U.S. state t...       false
# 1  Georgia recently became the first U.S. state t...       false
# 2  Georgia recently became the first U.S. state t...       false
# 3  Georgia recently became the first U.S. state t...       false
# 4  Georgia recently became the first U.S. state t...       false
#
#    date_published    date_updated  \
# 0  Nov 17th, 2016  Mar 20th, 2017
# 1  Nov 17th, 2016  Mar 20th, 2017
# 2  Nov 17th, 2016  Mar 20th, 2017
# 3  Nov 17th, 2016  Mar 20th, 2017
# 4  Nov 17th, 2016  Mar 20th, 2017
#
#                                             page_url  page_is_example  \
# 0  http://www.legis.ga.gov/Legislation/en-US/disp...            False
# 1  http://arabsinamerica.unc.edu/identity/veiling...            False
# 2        http://www.wisegeek.com/what-is-a-niqab.htm            False
# 3  http://www.wsbtv.com/news/local/new-bill-would...            False
# 4                 http://www.house-press.com/?p=6060            False
#
#    page_is_image_credit  page_is_archived  page_is_first_citation tags
# 0                 False             False                    True  NaN
# 1                 False             False                   False  NaN
# 2                 False             False                   False  NaN
# 3                 False             False                   False  NaN
# 4                 False             False                   False  NaN
# Found 9766 unique tokens.

# %%
# Pad input sequences
data = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
labels = to_categorical(np.asarray(labels),num_classes = len(list_labels))
print('Shape of data tensor:', data.shape)
print('Shape of label tensor:', labels.shape)
# Out:
# Shape of data tensor: (16865, 1000)
# Shape of label tensor: (16865, 7)

# %%
# Train test validation Split
from sklearn.model_selection import train_test_split

indices = np.arange(data.shape[0])
np.random.shuffle(indices)
data = data[indices]
labels = labels[indices]
x_train, x_test, y_train, y_test = train_test_split( data, labels, test_size=0.20, random_state=42)
#x_test, x_val, y_test, y_val = train_test_split( data, labels, test_size=0.50, random_state=42)
print('Size of train, validation, test:', len(y_train), len(y_test))

print('real & fake news in train,valt,test:')
print(y_train.sum(axis=0))
# print(y_val.sum(axis=0))
print(y_test.sum(axis=0))
# Out:
# Size of train, validation, test: 13492 3373
# real & fake news in train,valt,test:
# [ 393. 1161.  121. 2094. 7038.   34. 2651.]
# [  94.  319.   30.  524. 1727.   11.  668.]

# %%
#Using Pre-trained word embeddings
GLOVE_DIR = "data" 
embeddings_index = {}
f = open(os.path.join(GLOVE_DIR, 'C:/Users/spcbe/Documents/GitHub/Fake-News-Detection--master/dataset/glove.6B.100d.txt'), encoding="utf8")
for line in f:
    values = line.split()
    #print(values[1:])
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Total %s word vectors in Glove.' % len(embeddings_index))

embedding_matrix = np.random.random((len(word_index) + 1, EMBEDDING_DIM))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
        
embedding_layer = Embedding(len(word_index) + 1,
                            EMBEDDING_DIM,
                            weights=[embedding_matrix],
                            input_length=MAX_SEQUENCE_LENGTH)
# Out:
# Total 400000 word vectors in Glove.

# %%
# Simple CNN model
sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
embedded_sequences = embedding_layer(sequence_input)
l_cov1= Conv1D(128, 5, activation='relu')(embedded_sequences)
l_pool1 = MaxPooling1D(5)(l_cov1)
l_cov2 = Conv1D(128, 5, activation='relu')(l_pool1)
l_pool2 = MaxPooling1D(5)(l_cov2)
l_cov3 = Conv1D(128, 5, activation='relu')(l_pool2)
l_pool3 = MaxPooling1D(35)(l_cov3)  # global max pooling
l_flat = Flatten()(l_pool3)
l_dense = Dense(128, activation='relu')(l_flat)
preds = Dense(7, activation='softmax')(l_dense)

model = Model(sequence_input, preds)
model.compile(loss='categorical_crossentropy',
              optimizer='adadelta',
              metrics=['acc'])

print("Fitting the simple convolutional neural network model")
model.summary()
history = model.fit(x_train, y_train,
          epochs=3, batch_size=128)
# Out:
# Fitting the simple convolutional neural network model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 1000)              0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 1000, 100)         976700
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 996, 128)          64128
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 199, 128)          0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 195, 128)          82048
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 39, 128)           0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 35, 128)           82048
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 1, 128)            0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_6 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 1,222,339
# Trainable params: 1,222,339
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 13492/13492 [==============================] - 143s 11ms/step - loss: 1.3327 - acc: 0.5118
# Epoch 2/3
# 13492/13492 [==============================] - 138s 10ms/step - loss: 1.1795 - acc: 0.5627
# Epoch 3/3
# 13492/13492 [==============================] - 140s 10ms/step - loss: 0.8110 - acc: 0.7166

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
#plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'acc'])

# %%
# #convolutional approach
# convs = []
# filter_sizes = [3,4,5]

# sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
# embedded_sequences = embedding_layer(sequence_input)

# for fsz in filter_sizes:
#     l_conv = Conv1D(nb_filter=128,filter_length=fsz,activation='relu')(embedded_sequences)
#     l_pool = MaxPooling1D(5)(l_conv)
#     convs.append(l_pool)
    
# l_merge = Merge(mode='concat', concat_axis=1)(convs)
# l_cov1= Conv1D(filters=128, kernel_size=5, activation='relu')(l_merge)
# l_pool1 = MaxPooling1D(5)(l_cov1)
# l_cov2 = Conv1D(filters=128, kernel_size=5, activation='relu')(l_pool1)
# l_pool2 = MaxPooling1D(30)(l_cov2)
# l_flat = Flatten()(l_pool2)
# l_dense = Dense(128, activation='relu')(l_flat)
# preds = Dense(2, activation='softmax')(l_dense)

# model2 = Model(sequence_input, preds)
# model2.compile(loss='categorical_crossentropy',
#               optimizer='adadelta',
#               metrics=['acc'])

# print("Fitting a more complex convolutional neural network model")
# model2.summary()
# history2 = model2.fit(x_train, y_train, validation_data=(x_val, y_val),
#           epochs=3, batch_size=50)
# model2.save('model.h5')

# %%
# # list all data in history
# print(history2.history.keys())
# import matplotlib.pyplot as plt
# %matplotlib inline 
# # summarize history for accuracy
# plt.plot(history2.history['acc'])
# #plt.plot(history2.history['val_acc'])
# plt.title('model accuracy')
# plt.ylabel('accuracy')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper left')
# plt.show()
# # summarize history for loss
# plt.plot(history2.history['loss'])
# #plt.plot(history2.history['val_loss'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper left')
# plt.show()

# %%
# Test model 1
test_preds = model.predict(x_test)
test_preds = np.round(test_preds)
# correct_predictions = float(sum(test_preds == y_test)[0])
preds =[]
actual =[]
correct_predictions= 0
for i in range(len(test_preds)):
    y = np.argmax(y_test[i])
    x = np.argmax(test_preds[i])
    preds.append(x)
    actual.append(y)
#     x = a.index(1.0)
#     y = b.index(1.0)
    if x == y:
        correct_predictions+=1
print("Correct predictions:", correct_predictions)
print("Total number of test examples:", len(y_test))
print("Accuracy of model1: ", correct_predictions/float(len(y_test)))

# Creating the Confusion Matrix
from sklearn.metrics import confusion_matrix
x_pred = model.predict(x_test)
x_pred = np.round(x_pred)
x_pred = x_pred.argmax(1)
y_test_s = y_test.argmax(1)
cm = confusion_matrix(y_test_s, x_pred)
plt.matshow(cm, cmap=plt.cm.binary, interpolation='nearest')
plt.title('Confusion matrix - model1')
plt.colorbar()
plt.ylabel('expected label')
plt.xlabel('predicted label')
# plt.show()

# #Test model 2
# test_preds2 = model2.predict(x_test)
# test_preds2 = np.round(test_preds2)
# correct_predictions = float(sum(test_preds2 == y_test)[0])
# print("Correct predictions:", correct_predictions)
# print("Total number of test examples:", len(y_test))
# print("Accuracy of model2: ", correct_predictions/float(len(y_test)))

# # Creating the Confusion Matrix
# x_pred = model2.predict(x_test)
# x_pred = np.round(x_pred)
# x_pred = x_pred.argmax(1)
# y_test_s = y_test.argmax(1)
# cm = confusion_matrix(y_test_s, x_pred)
# plt.matshow(cm, cmap=plt.cm.binary, interpolation='nearest',)
# plt.title('Confusion matrix - model2')
# plt.colorbar()
# plt.ylabel('expected label')
# plt.xlabel('predicted label')
# plt.show()
# Out:
# Correct predictions: 2724
# Total number of test examples: 3373
# Accuracy of model1:  0.8075896827749778
# Text(0.5, 0, 'predicted label')

# %%
print(preds.count(0) , preds.count(1) , preds.count(2) , preds.count(3) , preds.count(4) , preds.count(5), preds.count(6) )
# Out:
# 499 209 0 374 1823 0 468

# %%
print(actual.count(0) , actual.count(1) , actual.count(2) , actual.count(3) , actual.count(4) , actual.count(5) , actual.count(6))
# Out:
# 94 319 30 524 1727 11 668

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.48391833091185066
# Test accuracy: 0.8609546398748957

# %%
# score = model2.evaluate(x_test, y_test, verbose=0)
# print('Test loss:', score[0])
# print('Test accuracy:', score[1])
