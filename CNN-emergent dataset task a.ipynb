# %%
import keras

# %%
from tensorflow.python.client import device_lib

print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11005415997189139472
# ]

# %%
import numpy as np
import pandas as pd
from collections import defaultdict
import re

from bs4 import BeautifulSoup

import sys
import os

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils.np_utils import to_categorical

from keras.layers import Embedding
from keras.layers import Dense, Input, Flatten
from keras.layers import Conv1D, MaxPooling1D, Embedding, Dropout
from keras.models import Model

MAX_SEQUENCE_LENGTH = 1000
MAX_NB_WORDS = 200000
EMBEDDING_DIM = 100
VALIDATION_SPLIT = 0.2

# %%
def clean_str(string):
    """
    Cleaning of dataset
    """
    string = re.sub(r"\\", "", string)    
    string = re.sub(r"\'", "", string)    
    string = re.sub(r"\"", "", string)    
    return string.strip().lower()

# %%
data_train = pd.read_csv('C:/Users/spcbe/Documents/GitHub/dataset/emergent_training_dataset.csv')
data_train
# Out:
#                                           emergent_page  \
# 0     http://www.emergent.info/disney-collector-is-f...
# 1     http://www.emergent.info/disney-collector-is-f...
# 2     http://www.emergent.info/disney-collector-is-f...
# 3     http://www.emergent.info/20-year-old-McDonalds...
# 4     http://www.emergent.info/20-year-old-McDonalds...
# 5     http://www.emergent.info/20-year-old-McDonalds...
# 6     http://www.emergent.info/20-year-old-McDonalds...
# 7     http://www.emergent.info/20-year-old-McDonalds...
# 8     http://www.emergent.info/20-year-old-McDonalds...
# 9     http://www.emergent.info/20-year-old-McDonalds...
# 10    http://www.emergent.info/20-year-old-McDonalds...
# 11    http://www.emergent.info/20-year-old-McDonalds...
# 12      http://www.emergent.info/tbs-speeds-up-Seinfeld
# 13      http://www.emergent.info/tbs-speeds-up-Seinfeld
# 14      http://www.emergent.info/tbs-speeds-up-Seinfeld
# 15      http://www.emergent.info/tbs-speeds-up-Seinfeld
# 16      http://www.emergent.info/tbs-speeds-up-Seinfeld
# 17      http://www.emergent.info/tbs-speeds-up-Seinfeld
# 18      http://www.emergent.info/tbs-speeds-up-Seinfeld
# 19      http://www.emergent.info/tbs-speeds-up-Seinfeld
# 20      http://www.emergent.info/tbs-speeds-up-Seinfeld
# 21      http://www.emergent.info/tbs-speeds-up-Seinfeld
# 22      http://www.emergent.info/tbs-speeds-up-Seinfeld
# 23      http://www.emergent.info/tbs-speeds-up-Seinfeld
# 24    http://www.emergent.info/Star-Wars-early-summe...
# 25    http://www.emergent.info/Star-Wars-early-summe...
# 26    http://www.emergent.info/Star-Wars-early-summe...
# 27    http://www.emergent.info/Star-Wars-early-summe...
# 28    http://www.emergent.info/Star-Wars-early-summe...
# 29    http://www.emergent.info/Star-Wars-early-summe...
# ...                                                 ...
# 2115  http://www.emergent.info/apple-12-inch-Macbook...
# 2116  http://www.emergent.info/apple-12-inch-Macbook...
# 2117  http://www.emergent.info/apple-12-inch-Macbook...
# 2118  http://www.emergent.info/apple-12-inch-Macbook...
# 2119  http://www.emergent.info/apple-12-inch-Macbook...
# 2120  http://www.emergent.info/apple-12-inch-Macbook...
# 2121  http://www.emergent.info/apple-12-inch-Macbook...
# 2122  http://www.emergent.info/apple-12-inch-Macbook...
# 2123  http://www.emergent.info/apple-12-inch-Macbook...
# 2124  http://www.emergent.info/apple-12-inch-Macbook...
# 2125  http://www.emergent.info/apple-12-inch-Macbook...
# 2126  http://www.emergent.info/apple-12-inch-Macbook...
# 2127  http://www.emergent.info/apple-12-inch-Macbook...
# 2128  http://www.emergent.info/apple-12-inch-Macbook...
# 2129  http://www.emergent.info/apple-12-inch-Macbook...
# 2130  http://www.emergent.info/Samsung-Apple-watch-p...
# 2131  http://www.emergent.info/Samsung-Apple-watch-p...
# 2132  http://www.emergent.info/Samsung-Apple-watch-p...
# 2133  http://www.emergent.info/Samsung-Apple-watch-p...
# 2134  http://www.emergent.info/apple-watch-store-app...
# 2135  http://www.emergent.info/apple-watch-store-app...
# 2136  http://www.emergent.info/apple-watch-store-app...
# 2137  http://www.emergent.info/apple-watch-store-app...
# 2138  http://www.emergent.info/apple-watch-platinum-...
# 2139  http://www.emergent.info/apple-watch-platinum-...
# 2140  http://www.emergent.info/apple-watch-platinum-...
# 2141  http://www.emergent.info/apple-watch-platinum-...
# 2142  http://www.emergent.info/apple-watch-platinum-...
# 2143  http://www.emergent.info/apple-watch-platinum-...
# 2144  http://www.emergent.info/apple-watch-platinum-...
#
#                                                   claim  \
# 0     Claim: The woman behind the hugely popular DC ...
# 1     Claim: The woman behind the hugely popular DC ...
# 2     Claim: The woman behind the hugely popular DC ...
# 3     Claim: Two Australian men kept a McDonald's Qu...
# 4     Claim: Two Australian men kept a McDonald's Qu...
# 5     Claim: Two Australian men kept a McDonald's Qu...
# 6     Claim: Two Australian men kept a McDonald's Qu...
# 7     Claim: Two Australian men kept a McDonald's Qu...
# 8     Claim: Two Australian men kept a McDonald's Qu...
# 9     Claim: Two Australian men kept a McDonald's Qu...
# 10    Claim: Two Australian men kept a McDonald's Qu...
# 11    Claim: Two Australian men kept a McDonald's Qu...
# 12    Claim: TBS speeds up Seinfeld episodes to fit ...
# 13    Claim: TBS speeds up Seinfeld episodes to fit ...
# 14    Claim: TBS speeds up Seinfeld episodes to fit ...
# 15    Claim: TBS speeds up Seinfeld episodes to fit ...
# 16    Claim: TBS speeds up Seinfeld episodes to fit ...
# 17    Claim: TBS speeds up Seinfeld episodes to fit ...
# 18    Claim: TBS speeds up Seinfeld episodes to fit ...
# 19    Claim: TBS speeds up Seinfeld episodes to fit ...
# 20    Claim: TBS speeds up Seinfeld episodes to fit ...
# 21    Claim: TBS speeds up Seinfeld episodes to fit ...
# 22    Claim: TBS speeds up Seinfeld episodes to fit ...
# 23    Claim: TBS speeds up Seinfeld episodes to fit ...
# 24    Claim: J.J. Abrams wants a summer release date...
# 25    Claim: J.J. Abrams wants a summer release date...
# 26    Claim: J.J. Abrams wants a summer release date...
# 27    Claim: J.J. Abrams wants a summer release date...
# 28    Claim: J.J. Abrams wants a summer release date...
# 29    Claim: J.J. Abrams wants a summer release date...
# ...                                                 ...
# 2115  Claim: Apple will launch a 12" MacBook Air in ...
# 2116  Claim: Apple will launch a 12" MacBook Air in ...
# 2117  Claim: Apple will launch a 12" MacBook Air in ...
# 2118  Claim: Apple will launch a 12" MacBook Air in ...
# 2119  Claim: Apple will launch a 12" MacBook Air in ...
# 2120  Claim: Apple will launch a 12" MacBook Air in ...
# 2121  Claim: Apple will launch a 12" MacBook Air in ...
# 2122  Claim: Apple will launch a 12" MacBook Air in ...
# 2123  Claim: Apple will launch a 12" MacBook Air in ...
# 2124  Claim: Apple will launch a 12" MacBook Air in ...
# 2125  Claim: Apple will launch a 12" MacBook Air in ...
# 2126  Claim: Apple will launch a 12" MacBook Air in ...
# 2127  Claim: Apple will launch a 12" MacBook Air in ...
# 2128  Claim: Apple will launch a 12" MacBook Air in ...
# 2129  Claim: Apple will launch a 12" MacBook Air in ...
# 2130  Claim: Samsung will supply application process...
# 2131  Claim: Samsung will supply application process...
# 2132  Claim: Samsung will supply application process...
# 2133  Claim: Samsung will supply application process...
# 2134  Claim: Apple will take appointments at Apple S...
# 2135  Claim: Apple will take appointments at Apple S...
# 2136  Claim: Apple will take appointments at Apple S...
# 2137  Claim: Apple will take appointments at Apple S...
# 2138  Claim: Apple is considering the release of a p...
# 2139  Claim: Apple is considering the release of a p...
# 2140  Claim: Apple is considering the release of a p...
# 2141  Claim: Apple is considering the release of a p...
# 2142  Claim: Apple is considering the release of a p...
# 2143  Claim: Apple is considering the release of a p...
# 2144  Claim: Apple is considering the release of a p...
#
#                                       claim_description claim_label  \
# 0     The channel has racked up more than 2.8 billio...  Unverified
# 1     The channel has racked up more than 2.8 billio...  Unverified
# 2     The channel has racked up more than 2.8 billio...  Unverified
# 3              They say it's the world's oldest burger.  Unverified
# 4              They say it's the world's oldest burger.  Unverified
# 5              They say it's the world's oldest burger.  Unverified
# 6              They say it's the world's oldest burger.  Unverified
# 7              They say it's the world's oldest burger.  Unverified
# 8              They say it's the world's oldest burger.  Unverified
# 9              They say it's the world's oldest burger.  Unverified
# 10             They say it's the world's oldest burger.  Unverified
# 11             They say it's the world's oldest burger.  Unverified
# 12    A video posted on YouTube, and then shared on ...  Unverified
# 13    A video posted on YouTube, and then shared on ...  Unverified
# 14    A video posted on YouTube, and then shared on ...  Unverified
# 15    A video posted on YouTube, and then shared on ...  Unverified
# 16    A video posted on YouTube, and then shared on ...  Unverified
# 17    A video posted on YouTube, and then shared on ...  Unverified
# 18    A video posted on YouTube, and then shared on ...  Unverified
# 19    A video posted on YouTube, and then shared on ...  Unverified
# 20    A video posted on YouTube, and then shared on ...  Unverified
# 21    A video posted on YouTube, and then shared on ...  Unverified
# 22    A video posted on YouTube, and then shared on ...  Unverified
# 23    A video posted on YouTube, and then shared on ...  Unverified
# 24    It was claimed that director JJ Abrams talked ...       FALSE
# 25    It was claimed that director JJ Abrams talked ...       FALSE
# 26    It was claimed that director JJ Abrams talked ...       FALSE
# 27    It was claimed that director JJ Abrams talked ...       FALSE
# 28    It was claimed that director JJ Abrams talked ...       FALSE
# 29    It was claimed that director JJ Abrams talked ...       FALSE
# ...                                                 ...         ...
# 2115  Size is allegedly one of many changes to come ...        TRUE
# 2116  Size is allegedly one of many changes to come ...        TRUE
# 2117  Size is allegedly one of many changes to come ...        TRUE
# 2118  Size is allegedly one of many changes to come ...        TRUE
# 2119  Size is allegedly one of many changes to come ...        TRUE
# 2120  Size is allegedly one of many changes to come ...        TRUE
# 2121  Size is allegedly one of many changes to come ...        TRUE
# 2122  Size is allegedly one of many changes to come ...        TRUE
# 2123  Size is allegedly one of many changes to come ...        TRUE
# 2124  Size is allegedly one of many changes to come ...        TRUE
# 2125  Size is allegedly one of many changes to come ...        TRUE
# 2126  Size is allegedly one of many changes to come ...        TRUE
# 2127  Size is allegedly one of many changes to come ...        TRUE
# 2128  Size is allegedly one of many changes to come ...        TRUE
# 2129  Size is allegedly one of many changes to come ...        TRUE
# 2130                                                NaN  Unverified
# 2131                                                NaN  Unverified
# 2132                                                NaN  Unverified
# 2133                                                NaN  Unverified
# 2134                                                NaN  Unverified
# 2135                                                NaN  Unverified
# 2136                                                NaN  Unverified
# 2137                                                NaN  Unverified
# 2138                                                NaN  Unverified
# 2139                                                NaN  Unverified
# 2140                                                NaN  Unverified
# 2141                                                NaN  Unverified
# 2142                                                NaN  Unverified
# 2143                                                NaN  Unverified
# 2144                                                NaN  Unverified
#
#                                                    tags  claim_source_domain  \
# 0     Daiane+DeJesus,DC+Toys+Collector,Porm,Sandy+Su...      dailymail.co.uk
# 1     Daiane+DeJesus,DC+Toys+Collector,Porm,Sandy+Su...      dailymail.co.uk
# 2     Daiane+DeJesus,DC+Toys+Collector,Porm,Sandy+Su...      dailymail.co.uk
# 3     Australia,Food,Hamburger,McDonald's,Quarter+Po...         facebook.com
# 4     Australia,Food,Hamburger,McDonald's,Quarter+Po...         facebook.com
# 5     Australia,Food,Hamburger,McDonald's,Quarter+Po...         facebook.com
# 6     Australia,Food,Hamburger,McDonald's,Quarter+Po...         facebook.com
# 7     Australia,Food,Hamburger,McDonald's,Quarter+Po...         facebook.com
# 8     Australia,Food,Hamburger,McDonald's,Quarter+Po...         facebook.com
# 9     Australia,Food,Hamburger,McDonald's,Quarter+Po...         facebook.com
# 10    Australia,Food,Hamburger,McDonald's,Quarter+Po...         facebook.com
# 11    Australia,Food,Hamburger,McDonald's,Quarter+Po...         facebook.com
# 12                                      Seinfeld,TBS,TV         avsforum.com
# 13                                      Seinfeld,TBS,TV         avsforum.com
# 14                                      Seinfeld,TBS,TV         avsforum.com
# 15                                      Seinfeld,TBS,TV         avsforum.com
# 16                                      Seinfeld,TBS,TV         avsforum.com
# 17                                      Seinfeld,TBS,TV         avsforum.com
# 18                                      Seinfeld,TBS,TV         avsforum.com
# 19                                      Seinfeld,TBS,TV         avsforum.com
# 20                                      Seinfeld,TBS,TV         avsforum.com
# 21                                      Seinfeld,TBS,TV         avsforum.com
# 22                                      Seinfeld,TBS,TV         avsforum.com
# 23                                      Seinfeld,TBS,TV         avsforum.com
# 24            iKwiz,J.J.+Abrams,Star+Wars,Video,YouTube     journalmetro.com
# 25            iKwiz,J.J.+Abrams,Star+Wars,Video,YouTube     journalmetro.com
# 26            iKwiz,J.J.+Abrams,Star+Wars,Video,YouTube     journalmetro.com
# 27            iKwiz,J.J.+Abrams,Star+Wars,Video,YouTube     journalmetro.com
# 28            iKwiz,J.J.+Abrams,Star+Wars,Video,YouTube     journalmetro.com
# 29            iKwiz,J.J.+Abrams,Star+Wars,Video,YouTube     journalmetro.com
# ...                                                 ...                  ...
# 2115             9to5+Mac,Apple,MacBook+Air,Mark+Gurman          9to5mac.com
# 2116             9to5+Mac,Apple,MacBook+Air,Mark+Gurman          9to5mac.com
# 2117             9to5+Mac,Apple,MacBook+Air,Mark+Gurman          9to5mac.com
# 2118             9to5+Mac,Apple,MacBook+Air,Mark+Gurman          9to5mac.com
# 2119             9to5+Mac,Apple,MacBook+Air,Mark+Gurman          9to5mac.com
# 2120             9to5+Mac,Apple,MacBook+Air,Mark+Gurman          9to5mac.com
# 2121             9to5+Mac,Apple,MacBook+Air,Mark+Gurman          9to5mac.com
# 2122             9to5+Mac,Apple,MacBook+Air,Mark+Gurman          9to5mac.com
# 2123             9to5+Mac,Apple,MacBook+Air,Mark+Gurman          9to5mac.com
# 2124             9to5+Mac,Apple,MacBook+Air,Mark+Gurman          9to5mac.com
# 2125             9to5+Mac,Apple,MacBook+Air,Mark+Gurman          9to5mac.com
# 2126             9to5+Mac,Apple,MacBook+Air,Mark+Gurman          9to5mac.com
# 2127             9to5+Mac,Apple,MacBook+Air,Mark+Gurman          9to5mac.com
# 2128             9to5+Mac,Apple,MacBook+Air,Mark+Gurman          9to5mac.com
# 2129             9to5+Mac,Apple,MacBook+Air,Mark+Gurman          9to5mac.com
# 2130  Apple+Watch,Apple+Watch+Components,BusinessKor...  businesskorea.co.kr
# 2131  Apple+Watch,Apple+Watch+Components,BusinessKor...  businesskorea.co.kr
# 2132  Apple+Watch,Apple+Watch+Components,BusinessKor...  businesskorea.co.kr
# 2133  Apple+Watch,Apple+Watch+Components,BusinessKor...  businesskorea.co.kr
# 2134  Apple+Watch,Daisuke+Wakabayashi,Wall+Street+Jo...              wsj.com
# 
# 2124  Apple Reportedly Preparing 12-inch MacBook Air...           for
# 2125  Apple's New MacBook Will Be A Thinner, Cleaner...           for
# 2126  Apple 12-Inch MacBook Air Details Emerge; Devi...           for
# 2127  One port to rule them all: Apple planning radi...           for
# 2128  12in Retina MacBook Air release date rumours: ...     observing
# 2129           Apple testing new super-thin MacBook Air     observing
# 2130  iPhone 6 Features Flood of Components Made by ...     observing
# 2131  Apple Reportedly Relying More Heavily on Samsu...     observing
# 2132  iPhone 6 and Even Apple Watch To Feature Samsu...     observing
# 2133  Everything We Currently Know About The Apple W...     observing
# 2134      Smartwatch Pushes Apple Into High-End Fashion           for
# 2135             The next Apple Watch could be platinum     observing
# 2136  You may be able to make appointments at the Ap...           for
# 2137  Apple to Take Reservations for Trying On Apple...           for
# 2138      Smartwatch Pushes Apple Into High-End Fashion           for
# 2139             The next Apple Watch could be platinum           for
# 2140  Apple saving money on the gold in Apple Watch ...           for
# 2141  Future Apple Watches could include platinum mo...     observing
# 2142  Apple to Take Reservations for Trying On Apple...           for
# 2143  Forget 18-karat gold, next-generation Apple Wa...     observing
# 2144  Is Apple already making plans for its next Watch?     observing
#
#      page_shares  page_order
# 0          4,982           1
# 1            530           2
# 2            275           3
# 3            121           1
# 4             54           2
# 5            134           3
# 6             73           4
# 7            177           5
# 8             58           6
# 9              2           7
# 10           425           8
# 11           362           9
# 12             2           1
# 13             5           2
# 14         1,156           3
# 15           172           4
# 16           225           5
# 17           787           6
# 18           287           7
# 19         1,314           8
# 20         3,094           9
# 21           288          10
# 22         1,336          11
# 23         2,559          12
# 24        25,408           1
# 25           312           2
# 26             0           3
# 27            83           4
# 28            84           5
# 29             0           6
# ...          ...         ...
# 2115         138           4
# 2116       3,168           5
# 2117       4,263           6
# 2118          99           7
# 2119       3,066           8
# 2120          86           9
# 2121         645          10
# 2122         521          11
# 2123       1,054          12
# 2124           1          13
# 2125         168          14
# 2126          15          15
# 2127         107          16
# 2128         588          17
# 2129       7,841          18
# 2130          24           1
# 2131         482           2
# 2132          11           3
# 2133         522           4
# 2134       2,716           1
# 2135       2,074           2
# 2136         116           3
# 2137         645           4
# 2138       2,716           1
# 2139       2,074           2
# 2140         166           3
# 2141          89           4
# 2142         645           5
# 2143           9           6
# 2144           5           7
#
# [2145 rows x 15 columns]

# %%
# Input Data preprocessing
# data_train = pd.read_csv('C:/Users/spcbe/Documents/GitHub/Fake-News-Detection--master/dataset/train.csv')
#data_train['label'] = data_train['label'].replace('FAKE',1)
#data_train['label'] = data_train['label'].replace('REAL',0)
print(data_train.columns)
print('What the raw input data looks like:')
print(data_train[0:5])
list_labels = list(set(data_train.claim_label))
texts = []
labels = []

for i in range(data_train.claim.shape[0]):
    text1 = str(data_train.claim_description[i])
    text = str(data_train.claim[i])
    texts.append(text+text1)
    labels.append(list_labels.index(data_train.claim_label[i]))
    
tokenizer = Tokenizer(num_words=MAX_NB_WORDS)
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
# Out:
# Index(['emergent_page', 'claim', 'claim_description', 'claim_label', 'tags',
#        'claim_source_domain', 'claim_course_url', 'date', 'body',
#        'page_domain', 'page_url', 'page_headline', 'page_position',
#        'page_shares', 'page_order'],
#       dtype='object')
# What the raw input data looks like:
#                                        emergent_page  \
# 0  http://www.emergent.info/disney-collector-is-f...
# 1  http://www.emergent.info/disney-collector-is-f...
# 2  http://www.emergent.info/disney-collector-is-f...
# 3  http://www.emergent.info/20-year-old-McDonalds...
# 4  http://www.emergent.info/20-year-old-McDonalds...
#
#                                                claim  \
# 0  Claim: The woman behind the hugely popular DC ...
# 1  Claim: The woman behind the hugely popular DC ...
# 2  Claim: The woman behind the hugely popular DC ...
# 3  Claim: Two Australian men kept a McDonald's Qu...
# 4  Claim: Two Australian men kept a McDonald's Qu...
#
#                                    claim_description claim_label  \
# 0  The channel has racked up more than 2.8 billio...  Unverified
# 1  The channel has racked up more than 2.8 billio...  Unverified
# 2  The channel has racked up more than 2.8 billio...  Unverified
# 3           They say it's the world's oldest burger.  Unverified
# 4           They say it's the world's oldest burger.  Unverified
#
#                                                 tags claim_source_domain  \
# 0  Daiane+DeJesus,DC+Toys+Collector,Porm,Sandy+Su...     dailymail.co.uk
# 1  Daiane+DeJesus,DC+Toys+Collector,Porm,Sandy+Su...     dailymail.co.uk
# 2  Daiane+DeJesus,DC+Toys+Collector,Porm,Sandy+Su...     dailymail.co.uk
# 3  Australia,Food,Hamburger,McDonald's,Quarter+Po...        facebook.com
# 4  Australia,Food,Hamburger,McDonald's,Quarter+Po...        facebook.com
#
#                                     claim_course_url       date  \
# 0  http://www.dailymail.co.uk/news/article-295824...  2/25/2017
# 1  http://www.dailymail.co.uk/news/article-295824...  2/25/2017
# 2  http://www.dailymail.co.uk/news/article-295824...  2/25/2017
# 3  https://www.facebook.com/pages/Can-This-20-Yea...  2/17/2017
# 4  https://www.facebook.com/pages/Can-This-20-Yea...  2/17/2017
#
#                                                 body      page_domain  \
# 0  The Daily Mail published a story on Feb 24 tha...  dailymail.co.uk
# 1  The Daily Mail published a story on Feb 24 tha...    nextshark.com
# 2  The Daily Mail published a story on Feb 24 tha...    inquisitr.com
# 3  Two friends,Casey Dean and Eduard Nitz, say th...     mirror.co.uk
# 4  Two friends,Casey Dean and Eduard Nitz, say th...     examiner.com
#
#                                             page_url  \
# 0  http://www.dailymail.co.uk/news/article-295824...
# 1  http://nextshark.com/revealed-woman-behind-5-m...
# 2  http://www.inquisitr.com/1870478/former-porn-s...
# 3  http://www.mirror.co.uk/news/weird-news/worlds...
# 4  http://www.examiner.com/article/20-year-old-bu...
#
#                                        page_headline page_position  \
# 0  Mystery woman behind the 'richest hands on the...           for
# 1  REVEALED: Woman Behind $5 Million Per Year You...           for
# 2  Former Porn Star Behind YouTube Sensation ‘DC ...           for
# 3  Is this the world's oldest burger? Man claims ...     observing
# 4  20-year-old burger: McDonald's Quarter Pounder...           for
#
#   page_shares  page_order
# 0       4,982           1
# 1         530           2
# 2         275           3
# 3         121           1
# 4          54           2
# Found 1306 unique tokens.

# %%
# Pad input sequences
data = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
labels = to_categorical(np.asarray(labels),num_classes = len(list_labels))
print('Shape of data tensor:', data.shape)
print('Shape of label tensor:', labels.shape)
# Out:
# Shape of data tensor: (2145, 1000)
# Shape of label tensor: (2145, 3)

# %%
# Train test validation Split
from sklearn.model_selection import train_test_split

indices = np.arange(data.shape[0])
np.random.shuffle(indices)
data = data[indices]
labels = labels[indices]
x_train, x_test, y_train, y_test = train_test_split( data, labels, test_size=0.20, random_state=42)
#x_test, x_val, y_test, y_val = train_test_split( data, labels, test_size=0.50, random_state=42)
print('Size of train, validation, test:', len(y_train), len(y_test))

print('real & fake news in train,valt,test:')
print(y_train.sum(axis=0))
# print(y_val.sum(axis=0))
print(y_test.sum(axis=0))
# Out:
# Size of train, validation, test: 1716 429
# real & fake news in train,valt,test:
# [686. 595. 435.]
# [171. 142. 116.]

# %%
#Using Pre-trained word embeddings
GLOVE_DIR = "data" 
embeddings_index = {}
f = open(os.path.join(GLOVE_DIR, 'C:/Users/spcbe/Documents/GitHub/Fake-News-Detection--master/dataset/glove.6B.100d.txt'), encoding="utf8")
for line in f:
    values = line.split()
    #print(values[1:])
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Total %s word vectors in Glove.' % len(embeddings_index))

embedding_matrix = np.random.random((len(word_index) + 1, EMBEDDING_DIM))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
        
embedding_layer = Embedding(len(word_index) + 1,
                            EMBEDDING_DIM,
                            weights=[embedding_matrix],
                            input_length=MAX_SEQUENCE_LENGTH)
# Out:
# Total 400000 word vectors in Glove.

# %%
# CNN model
sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
embedded_sequences = embedding_layer(sequence_input)
l_cov1= Conv1D(128, 5, activation='relu')(embedded_sequences)
l_pool1 = MaxPooling1D(5)(l_cov1)
l_cov2 = Conv1D(128, 5, activation='relu')(l_pool1)
l_pool2 = MaxPooling1D(5)(l_cov2)
l_cov3 = Conv1D(128, 5, activation='relu')(l_pool2)
l_pool3 = MaxPooling1D(35)(l_cov3)  # global max pooling
l_flat = Flatten()(l_pool3)
l_dense = Dense(128, activation='relu')(l_flat)
preds = Dense(len(list_labels), activation='softmax')(l_dense)

model = Model(sequence_input, preds)
model.compile(loss='categorical_crossentropy',
              optimizer='adadelta',
              metrics=['acc'])

print("Fitting the simple convolutional neural network model")
model.summary()
history = model.fit(x_train, y_train,
          epochs=3, batch_size=128)
# Out:
# Fitting the simple convolutional neural network model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 1000)              0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 1000, 100)         130700
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 996, 128)          64128
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 199, 128)          0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 195, 128)          82048
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 39, 128)           0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 35, 128)           82048
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 1, 128)            0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_6 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 375,823
# Trainable params: 375,823
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 1716/1716 [==============================] - 15s 9ms/step - loss: 1.0812 - acc: 0.4172
# Epoch 2/3
# 1716/1716 [==============================] - 16s 9ms/step - loss: 0.8779 - acc: 0.6212
# Epoch 3/3
# 1716/1716 [==============================] - 16s 9ms/step - loss: 0.6450 - acc: 0.7389

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
#plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'acc'])

# %%
# #convolutional approach
# convs = []
# filter_sizes = [3,4,5]

# sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
# embedded_sequences = embedding_layer(sequence_input)

# for fsz in filter_sizes:
#     l_conv = Conv1D(nb_filter=128,filter_length=fsz,activation='relu')(embedded_sequences)
#     l_pool = MaxPooling1D(5)(l_conv)
#     convs.append(l_pool)
    
# l_merge = Merge(mode='concat', concat_axis=1)(convs)
# l_cov1= Conv1D(filters=128, kernel_size=5, activation='relu')(l_merge)
# l_pool1 = MaxPooling1D(5)(l_cov1)
# l_cov2 = Conv1D(filters=128, kernel_size=5, activation='relu')(l_pool1)
# l_pool2 = MaxPooling1D(30)(l_cov2)
# l_flat = Flatten()(l_pool2)
# l_dense = Dense(128, activation='relu')(l_flat)
# preds = Dense(2, activation='softmax')(l_dense)

# model2 = Model(sequence_input, preds)
# model2.compile(loss='categorical_crossentropy',
#               optimizer='adadelta',
#               metrics=['acc'])

# print("Fitting a more complex convolutional neural network model")
# model2.summary()
# history2 = model2.fit(x_train, y_train, validation_data=(x_val, y_val),
#           epochs=3, batch_size=50)
# model2.save('model.h5')

# %%
# # list all data in history
# print(history2.history.keys())
# import matplotlib.pyplot as plt
# %matplotlib inline 
# # summarize history for accuracy
# plt.plot(history2.history['acc'])
# #plt.plot(history2.history['val_acc'])
# plt.title('model accuracy')
# plt.ylabel('accuracy')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper left')
# plt.show()
# # summarize history for loss
# plt.plot(history2.history['loss'])
# #plt.plot(history2.history['val_loss'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper left')
# plt.show()

# %%
# Test model 1
test_preds = model.predict(x_test)
test_preds = np.round(test_preds)
# correct_predictions = float(sum(test_preds == y_test)[0])
preds =[]
actual =[]
correct_predictions= 0
for i in range(len(test_preds)):
    y = np.argmax(y_test[i])
    x = np.argmax(test_preds[i])
    preds.append(x)
    actual.append(y)
#     x = a.index(1.0)
#     y = b.index(1.0)
    if x == y:
        correct_predictions+=1
print("Correct predictions:", correct_predictions)
print("Total number of test examples:", len(y_test))
print("Accuracy of model1: ", correct_predictions/float(len(y_test)))

# Creating the Confusion Matrix
from sklearn.metrics import confusion_matrix
x_pred = model.predict(x_test)
x_pred = np.round(x_pred)
x_pred = x_pred.argmax(1)
y_test_s = y_test.argmax(1)
cm = confusion_matrix(y_test_s, x_pred)
plt.matshow(cm, cmap=plt.cm.binary, interpolation='nearest')
plt.title('Confusion matrix - model1')
plt.colorbar()
plt.ylabel('expected label')
plt.xlabel('predicted label')
# plt.show()

# #Test model 2
# test_preds2 = model2.predict(x_test)
# test_preds2 = np.round(test_preds2)
# correct_predictions = float(sum(test_preds2 == y_test)[0])
# print("Correct predictions:", correct_predictions)
# print("Total number of test examples:", len(y_test))
# print("Accuracy of model2: ", correct_predictions/float(len(y_test)))

# # Creating the Confusion Matrix
# x_pred = model2.predict(x_test)
# x_pred = np.round(x_pred)
# x_pred = x_pred.argmax(1)
# y_test_s = y_test.argmax(1)
# cm = confusion_matrix(y_test_s, x_pred)
# plt.matshow(cm, cmap=plt.cm.binary, interpolation='nearest',)
# plt.title('Confusion matrix - model2')
# plt.colorbar()
# plt.ylabel('expected label')
# plt.xlabel('predicted label')
# plt.show()
# Out:
# Correct predictions: 379
# Total number of test examples: 429
# Accuracy of model1:  0.8834498834498834
# Text(0.5, 0, 'predicted label')

# %%
print(preds.count(0) , preds.count(1) , preds.count(2) )
# Out:
# 221 134 74

# %%
print(actual.count(0) , actual.count(1) , actual.count(2))
# Out:
# 171 142 116

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.2571481481229231
# Test accuracy: 0.9207459208848593

# %%
# score = model2.evaluate(x_test, y_test, verbose=0)
# print('Test loss:', score[0])
# print('Test accuracy:', score[1])
